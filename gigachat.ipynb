# %%
import json
from utils.utils import get_lev, get_user_station, get_user_dates, preprocessing
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import pandas as pd
from openai import OpenAI
# Out:
# /Users/alexander/Учёба/ХАКАТОНЫ/Nuclear Hack/nuclear-hack/.venv/lib/python3.11/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
date_now = '2022-09-01'
user_message = 'Пр-кт Верн за вчера'

# %%
# %timeit

user_station = get_user_station(user_message=user_message)
user_dates = get_user_dates(user_message=user_message, date_now=date_now)
# Out:
# /Users/alexander/Учёба/ХАКАТОНЫ/Nuclear Hack/nuclear-hack/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ngw.devices.sberbank.ru'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/alexander/Учёба/ХАКАТОНЫ/Nuclear Hack/nuclear-hack/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'gigachat.devices.sberbank.ru'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
user_station
# Out:
# 'Пр-кт Верн'

# %%
user_dates
# Out:
# {'end_date': '2022-08-31 23:59', 'start_date': '2021-08-31 00:00'}

# %%
all_station = pd.read_excel("Data/пп_станции.xlsx")
all_station = preprocessing(all_station)
all_station
# Out:
# /Users/alexander/Учёба/ХАКАТОНЫ/Nuclear Hack/nuclear-hack/utils/utils.py:340: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Станция'] = df['Станция'].replace(rename_dict)
#                     Станция  Номер линии             Линия  2024-01-01 00:00  \
# 0     Бульвар Рокоссовского            8    СОКОЛЬНИЧЕСКАЯ              4835
# 1              Черкизовская            8    СОКОЛЬНИЧЕСКАЯ             15638
# 2    Преображенская площадь            8    СОКОЛЬНИЧЕСКАЯ             17117
# 3                Сокольники            8    СОКОЛЬНИЧЕСКАЯ              5465
# 4            Красносельская            8    СОКОЛЬНИЧЕСКАЯ              1727
# ..                      ...          ...               ...               ...
# 316                 Пыхтино         1691  СОЛНЦЕВСКАЯ ЛИН.              4290
# 317        Аэропорт Внуково         1691  СОЛНЦЕВСКАЯ ЛИН.             14178
# 318               Яхромская           18        ЛЮБЛИНСКАЯ             12536
# 319               Лианозово           18        ЛЮБЛИНСКАЯ              5489
# 320                  Физтех           18        ЛЮБЛИНСКАЯ              5404
#
#      2024-01-02 00:00  2024-01-03 00:00  2024-01-04 00:00  2024-01-05 00:00  \
# 0                2722             11209              2561             13714
# 1                3999              7029             15991              6496
# 2               17068              5004              2811              8365
# 3               14176             15017              5573             18759
# 4               19561             11373              8936              7746
# ..                ...               ...               ...               ...
# 316             11124              8035             10988             14040
# 317              7545             13950             17569             19801
# 318              3864             17189             14798             14759
# 319             16046              8603             16496              5616
# 320              4969              5933              5997              3834
#
#      2024-01-06 00:00  2024-01-07 00:00  ...  2024-03-25 00:00  \
# 0               15740              5816  ...              7792
# 1                6924             11353  ...             17814
# 2               13309             15090  ...              2349
# 3               15545             15972  ...             19196
# 4                4581             16152  ...              9980
# ..                ...               ...  ...               ...
# 316             12439             13075  ...             10249
# 317             13153             15277  ...              4608
# 318             16395              6341  ...              2056
# 319              8357             16304  ...              2921
# 320             15037              2938  ...             11708
#
#      2024-03-26 00:00  2024-03-27 00:00  2024-03-28 00:00  2024-03-29 00:00  \
# 0               14831             12097             17624              1217
# 1               12372             13030              6623              9721
# 2               11940             13961              6852             10961
# 3                3010              6793             15041             12051
# 4                9929              2055             18134             14682
# ..                ...               ...               ...               ...
# 316              3981             16549              1628             13114
# 317             13327             19943              6449             18352
# 318             17161              8856              5655             19023
# 319              1860              2118              5543              3349
# 320             11540             11996              4115              4534
#
#      2024-03-30 00:00  2024-03-31 00:00  2024-04-01 00:00  2024-04-02 00:00  \
# 0               12742             13998              2905             15113
# 1               10015             14864              7991              5441
# 2                4001              7265              6556              1132
# 3                9446              6409              6488             10083
# 4                5965             10725             15424             19339
# ..                ...               ...               ...               ...
# 316             16827             13176             18903             16045
# 317              5761              8656             13493             10257
# 318              3563              9180             12491             19663
# 319              9070             12203              2959              8499
# 320              9822              9793              9897              2893
#
#      2024-04-03 00:00
# 0               16671
# 1                6248
# 2               14094
# 3               18651
# 4                7391
# ..                ...
# 316              8390
# 317             15787
# 318              9813
# 319             18978
# 320              1476
#
# [309 rows x 97 columns]

# %%
# %time

get_lev(metro_data=all_station, user_station=user_station)
# Out:
# CPU times: user 1 µs, sys: 0 ns, total: 1 µs
# Wall time: 2.86 µs
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 get_ipython().run_line_magic('time', '')
# ----> 3 get_lev(metro_data=all_station, user_station=user_station)["0"]
#
# TypeError: string indices must be integers, not 'str'
