# %%
import json
from utils.utils import get_lev, get_user_station, get_user_dates
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import pandas as pd
from openai import OpenAI

# %%
date_now = '2022-09-01'
user_message = 'Пр-кт Верн за вчера'

# %%
# %timeit

user_station = get_user_station(user_message=user_message)
user_dates = get_user_dates(user_message=user_message, date_now=date_now)
# Out:
# /Users/alexander/Учёба/ХАКАТОНЫ/Nuclear Hack/nuclear-hack/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ngw.devices.sberbank.ru'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/alexander/Учёба/ХАКАТОНЫ/Nuclear Hack/nuclear-hack/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'gigachat.devices.sberbank.ru'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
user_station
# Out:
# 'Пр-кт Верн'

# %%
user_dates
# Out:
# {'end_date': '2022-08-31 23:59', 'start_date': '2022-08-30 00:00'}

# %%
all_station = pd.read_csv("Data/станции.csv")
all_station
# Out:
#                     Станция  Номер линии             Линия  4/3/2024  \
# 0     Бульвар Рокоссовского            8    СОКОЛЬНИЧЕСКАЯ     16671
# 1              Черкизовская            8    СОКОЛЬНИЧЕСКАЯ      6248
# 2    Преображенская площадь            8    СОКОЛЬНИЧЕСКАЯ     14094
# 3             Сокольники СЛ            8    СОКОЛЬНИЧЕСКАЯ     18651
# 4            Красносельская            8    СОКОЛЬНИЧЕСКАЯ      7391
# ..                      ...          ...               ...       ...
# 316        Аэропорт Внуково         1691  СОЛНЦЕВСКАЯ ЛИН.     15787
# 317               Яхромская           18        ЛЮБЛИНСКАЯ      9813
# 318               Лианозово           18        ЛЮБЛИНСКАЯ     18978
# 319                  Физтех           18        ЛЮБЛИНСКАЯ      1476
# 320            Текстильщики         1749               БКЛ     18055
#
#      4/2/2024  4/1/2024  3/31/2024  3/30/2024  3/29/2024  3/28/2024  ...  \
# 0       15113      2905      13998      12742       1217      17624  ...
# 1        5441      7991      14864      10015       9721       6623  ...
# 2        1132      6556       7265       4001      10961       6852  ...
# 3       10083      6488       6409       9446      12051      15041  ...
# 4       19339     15424      10725       5965      14682      18134  ...
# ..        ...       ...        ...        ...        ...        ...  ...
# 316     10257     13493       8656       5761      18352       6449  ...
# 317     19663     12491       9180       3563      19023       5655  ...
# 318      8499      2959      12203       9070       3349       5543  ...
# 319      2893      9897       9793       9822       4534       4115  ...
# 320     18422     14815      16915       6052      17560      14126  ...
#
#      1/10/2024  1/9/2024  1/8/2024  1/7/2024  1/6/2024  1/5/2024  1/4/2024  \
# 0         7280      4669      3812      5816     15740     13714      2561
# 1        13486      5061      3663     11353      6924      6496     15991
# 2         8176      9745     13281     15090     13309      8365      2811
# 3         3637     14001     12049     15972     15545     18759      5573
# 4        14194      7615      9321     16152      4581      7746      8936
# ..         ...       ...       ...       ...       ...       ...       ...
# 316       9654     17815     12401     15277     13153     19801     17569
# 317      12471     17980      2322      6341     16395     14759     14798
# 318      17639     14071     17237     16304      8357      5616     16496
# 319      16336     17256     14147      2938     15037      3834      5997
# 320       4330     17175      1590     19487     11503     13438      7997
#
#      1/3/2024  1/2/2024  1/1/2024
# 0       11209      2722      4835
# 1        7029      3999     15638
# 2        5004     17068     17117
# 3       15017     14176      5465
# 4       11373     19561      1727
# ..        ...       ...       ...
# 316     13950      7545     14178
# 317     17189      3864     12536
# 318      8603     16046      5489
# 319      5933      4969      5404
# 320     10796     11741      1741
#
# [321 rows x 97 columns]

# %%
# %time

get_lev(metro_data=all_station, user_station=user_station)
# Out:
# CPU times: user 1e+03 ns, sys: 1e+03 ns, total: 2 µs
# Wall time: 3.1 µs
#                   Станция  Расстояние Ливинштейна             Линия
# 189      Лермонтовский пр                      86  ТАГАНСК-КРАСНОПР
# 16   Проспект Вернадского                      72    СОКОЛЬНИЧЕСКАЯ
# 296  Проспект Вернадского                      72               БКЛ
