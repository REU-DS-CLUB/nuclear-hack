# %%
import json
from utils.utils import get_lev, get_user_station, get_user_dates
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import pandas as pd
from openai import OpenAI

# %%
date_now = '2022-09-01'
user_message = 'Пр-кт Верн за вчера'

# %%
# %timeit

user_station = get_user_station(user_message=user_message)
user_dates = get_user_dates(user_message=user_message, date_now=date_now)
# Out:
# /Users/alexander/Учёба/ХАКАТОНЫ/Nuclear Hack/nuclear-hack/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ngw.devices.sberbank.ru'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/alexander/Учёба/ХАКАТОНЫ/Nuclear Hack/nuclear-hack/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'gigachat.devices.sberbank.ru'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
user_station
# Out:
# 'Пр-кт Верн'

# %%
user_dates
# Out:
# {'end_date': '2022-08-31 00:00', 'start_date': '2021-09-01 00:00'}

# %%
all_station = pd.read_csv("Data/станции.csv")
all_station
# Out:
#                     Станция  Номер линии           Линия  01-01-2024  \
# 0     Бульвар Рокоссовского          8.0  СОКОЛЬНИЧЕСКАЯ      4835.0
# 1              Черкизовская          8.0  СОКОЛЬНИЧЕСКАЯ     15638.0
# 2    Преображенская площадь          8.0  СОКОЛЬНИЧЕСКАЯ     17117.0
# 3                Сокольники          8.0  СОКОЛЬНИЧЕСКАЯ      5465.0
# 4            Красносельская          8.0  СОКОЛЬНИЧЕСКАЯ      1727.0
# ..                      ...          ...             ...         ...
# 317                  Физтех         18.0      ЛЮБЛИНСКАЯ         NaN
# 318            Текстильщики       1749.0             БКЛ         NaN
# 319                     NaN          NaN             NaN      8366.0
# 320                     NaN          NaN             NaN      5506.0
# 321                     NaN          NaN             NaN     12536.0
#
#      02-01-2024  03-01-2024  04-01-2024  05-01-2024  06-01-2024  07-01-2024  \
# 0        2722.0     11209.0      2561.0     13714.0     15740.0      5816.0
# 1        3999.0      7029.0     15991.0      6496.0      6924.0     11353.0
# 2       17068.0      5004.0      2811.0      8365.0     13309.0     15090.0
# 3       14176.0     15017.0      5573.0     18759.0     15545.0     15972.0
# 4       19561.0     11373.0      8936.0      7746.0      4581.0     16152.0
# ..          ...         ...         ...         ...         ...         ...
# 317         NaN         NaN         NaN         NaN         NaN         NaN
# 318         NaN         NaN         NaN         NaN         NaN         NaN
# 319     14347.0     19469.0      6080.0     16375.0      9812.0      2909.0
# 320      3917.0      4036.0      4343.0     17258.0     13939.0      6849.0
# 321      3864.0     17189.0     14798.0     14759.0     16395.0      6341.0
#
#      ...  25-03-2024  26-03-2024  27-03-2024  28-03-2024  29-03-2024  \
# 0    ...      7792.0     14831.0     12097.0     17624.0      1217.0
# 1    ...     17814.0     12372.0     13030.0      6623.0      9721.0
# 2    ...      2349.0     11940.0     13961.0      6852.0     10961.0
# 3    ...     19196.0      3010.0      6793.0     15041.0     12051.0
# 4    ...      9980.0      9929.0      2055.0     18134.0     14682.0
# ..   ...         ...         ...         ...         ...         ...
# 317  ...         NaN         NaN         NaN         NaN         NaN
# 318  ...         NaN         NaN         NaN         NaN         NaN
# 319  ...     10043.0      1997.0      1237.0     11416.0     12598.0
# 320  ...     10614.0     18644.0      6544.0     12297.0     14118.0
# 321  ...      2056.0     17161.0      8856.0      5655.0     19023.0
#
#      30-03-2024  31-03-2024  01-04-2024  02-04-2024  03-04-2024
# 0       12742.0     13998.0      2905.0     15113.0     16671.0
# 1       10015.0     14864.0      7991.0      5441.0      6248.0
# 2        4001.0      7265.0      6556.0      1132.0     14094.0
# 3        9446.0      6409.0      6488.0     10083.0     18651.0
# 4        5965.0     10725.0     15424.0     19339.0      7391.0
# ..          ...         ...         ...         ...         ...
# 317         NaN         NaN         NaN         NaN         NaN
# 318         NaN         NaN         NaN         NaN         NaN
# 319      1050.0     16536.0     10575.0     14669.0      9513.0
# 320     12441.0     12672.0     12275.0     17090.0     11960.0
# 321      3563.0      9180.0     12491.0     19663.0      9813.0
#
# [322 rows x 97 columns]

# %%
# %time

get_lev(metro_data=all_station, user_station=user_station)
# Out:
# CPU times: user 1 µs, sys: 1e+03 ns, total: 2 µs
# Wall time: 1.91 µs
#                   Станция  Расстояние Ливинштейна           Линия
# 295  Проспект Вернадского                      72             БКЛ
# 16   Проспект Вернадского                      72  СОКОЛЬНИЧЕСКАЯ
# 223         Верхние Котлы                      58             МЦК
